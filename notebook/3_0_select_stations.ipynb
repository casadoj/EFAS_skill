# %% [markdown]
# # Select stations
# ***
#
# __Author__: Chus Casado<br>
# __Date__:   23-02-2023<br>
#
# __Introduction__:<br>
# The objectives of this notebook are two:
#
# * To select a subset of study points in the catchment.
# * To count the number of flood events that occurred in the catchment during the period from 14-10-2020 and 31-12-2022.
#
# I consider a flood event each time that the discharge time series goes over the 5-year discharge return period, which is not the same as the number of timesteps at which discharge exceeds the threshod. For every exceeding period, we count one event, no matter if the event lasted 6 h or several days.
#
# To avoid that the correlation between river points affects the result of the EFAS notification skill assessment, I will try different procedures to select study points.
#
# To make the study more comprehensible and to make sure that the data of the reporting points is correct, the whole notebook focuses on the Ebro River catchment.
#
# __Tasks to do__:<br>
# * [x] Remove stations too close.
#     * [x] According to area increment between stations in the same river.
#     * [x] According to correlation between the discharge timeseries. From each pair of highly correlated stations one must be removed; the election of which one from the pair to remove is important!
#     * [x]
#     * [x] According to correlation only for highflows. I consider high flow when discharge exceeds the 1.5 return period
#
# Possible solutions:
# * [x] Apply the correlation procedure event-wise, so that it doesn't eliminate the minor events
# * [x] Apply the correlation procedure to the subset of stations with some flood event, so that a station with no events does not remove a highly correlated station that in fact had events.
# * Change thresholds:
#     * [x] Increase the area increment threshold in order to remove more stations, hence, reduce correlation.
#     * [x] Increase the correlation threshold to be more restrictive and remove less stations.Possible solutions:
# * [x] Apply the correlation procedure event-wise, so that it doesn't eliminate the minor events
# * [x] Apply the correlation procedure to the subset of stations with some flood event, so that a station with no events does not remove a highly correlated station that in fact had events.
# * Change thresholds:
#     * [x] Increase the area increment threshold in order to remove more stations, hence, reduce correlation.
#     * [x] Increase the correlation threshold to be more restrictive and remove less stations.

# %%
import os
import glob
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import cartopy.crs as ccrs
import cartopy.feature as cf
from datetime import datetime, timedelta
import seaborn as sns

path_root = os.getcwd()

import warnings
warnings.filterwarnings("ignore")

os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd

os.chdir('../py/')
from notifications import *
os.chdir(path_root)

# %%
# correlation threshold
rho = .9

# area threshold
area = 1000

# %%
# load table of fixed reporting points
stations = pd.read_csv('../data/Station-2022-10-27v12.csv', index_col='station_id')
stations.index = stations.index.astype(str)
# filter stations and fields
mask = (stations['DrainingArea.km2.LDD'] >= area) & (stations.FixedRepPoint == True) # (stations.EC_calib == 3)#& ((stations.EC_calib != 0) & (stations.EC_calib != np.nan))
stations = stations.loc[mask, ['StationName', 'LisfloodX', 'LisfloodY', 'DrainingArea.km2.LDD', 'Catchment', 'River', 'EC_Catchments', 'Country code']]
stations.columns = stations.columns = ['name', 'X', 'Y', 'area', 'subcatchment', 'river', 'catchment', 'country']
stations[['strahler', 'pfafstetter']] = np.nan

# load shapefile with edited river and catchment names
points_edited = gpd.read_file('../data/GIS/fixed_report_points_500.shp')
points_edited.set_index('station_id', inplace=True, drop=True)
points_edited = points_edited[['StationNam', 'LisfloodX', 'LisfloodY', 'DrainingAr', 'Subcatchme',
                               'River', 'Catchment', 'Country co', 'strahler', 'pfafstette']]
points_edited.columns = stations.columns
# select points with a Pfafstetter code
mask = points_edited.pfafstetter.isnull()
points_edited = points_edited.loc[~mask]

# correct names of catchments and rivers
ids = list(set(stations.index).intersection(points_edited.index))
stations = stations.loc[ids]
for id in ids:
    for var in ['subcatchment', 'river', 'catchment']:
        if points_edited.loc[id, var] != np.nan:
            stations.loc[id, var] = points_edited.loc[id, var]

# add subcatchment and river order
stations.loc[ids, ['strahler', 'pfafstetter']] = points_edited.loc[ids, ['strahler', 'pfafstetter']]

# rename columns
#stations.columns = ['name', 'X', 'Y', 'area', 'subcatchment', 'river', 'catchment', 'country', 'strahler', 'subcatchment_order']

print('no. stations:\t{0}'.format(stations.shape[0]))
# Out:
# no. stations:	1943

# %%
# shapefile of rivers of Europe
rivers_shp = gpd.read_file(f'../data/GIS/RiversForWebPage_EU_ready.shp')

# %%
catchments = np.sort(stations.catchment.unique())

for catchment in catchments:
    
    print(f'\n{catchment.upper()}')
    print('-' * len(catchment))

    out_folder = f'../results/{catchment}/'
    if os.path.exists(out_folder) is False:
        os.makedirs(out_folder)
        
    out_file = f'{out_folder}points_selected.csv'
    if os.path.exists(out_file):
        continue

    # extract stations in the catchment
    stn_cat = stations.loc[stations.catchment == catchment].copy()
    stn_cat.sort_values(['area'], ascending=True, inplace=True)
    stn_cat.sort_values('pfafstetter', ascending=True, inplace=True)
    print('no. stations in the {0} catchment:\t{1}'.format(catchment, stn_cat.shape[0]))

    # shapefile with rivers
    rivers_cat = rivers_shp.loc[rivers_shp.BASIN == catchment]

    # load thresholds and extract 5-year discharge
    path_reanalysis = f'../data/thresholds/'
    thresholds = xr.open_dataset(f'{path_reanalysis}return_levels.nc')

    # coordinate arrays necessary to extract the data
    x = xr.DataArray(stn_cat.X, dims='id')
    y = xr.DataArray(stn_cat.Y, dims='id')

    # extract thresholds for each return period and station
    variables = list(thresholds.keys())
    for var in variables:
        # extract X-year discharge for the stations
        da = thresholds[var].sel(x=x, y=y, method='nearest')

        # add threshold to the stations data frame
        stn_cat[var] = da.data

    # load discharge reanalysis data
    files = glob.glob(f'../data/discharge/reanalysis/*202*.csv')
    if 'dis' in locals():
        del dis
    for file in files:
        temp = pd.read_csv(file, parse_dates=True, index_col=0)
        if 'dis' in locals():
            dis = pd.concat((dis, temp), axis=0)
        else:
            dis = temp.copy()
        del temp

    # cut the timeseries from 14-10-2020 12 pm and the selected reporting points
    dis_cat = dis.loc['2020-10-14 12:00:00':, stn_cat.index]

    print('Discharge timeseries:\n{0}\ttimesteps\n{1}\tstations'.format(*dis_cat.shape))

    # return period
    rp = 5

    # IDENTIFY EVENTS
    # ---------------

    # identify events only with upper bound
    events = identify_events(dis_cat, stn_cat[f'rl{rp}'])

    # count number of events per station
    col = f'n_events_{rp}'
    stn_cat[col] = events.sum()
    print('no. stations with at least one event:\t{0}'.format((stn_cat[col] > 0).sum()))
    print('total no. events:\t\t\t{0}'.format(stn_cat[col].sum()))


    if events.sum().sum() > 0:

        # PLOT MAP
        # # --------
        # plt.figure()
        # plot_events_map(stn_cat.X, stn_cat.Y, stn_cat[col], rivers=rivers_cat, size=20)

        # PLOT TIMESERIES
        # ---------------

        # Select the stations in a catchment
        mask = stn_cat[col] > 0
        stns = stn_cat.loc[mask].index#.sort_values(['subcatchment_order', 'strahler']).index
        # plot timeseries 
        for stn in stns:
            title = '{0} - {1} ({2}) - {3:.0f} km2 ({4:.0f})'.format(stn, *stn_cat.loc[stn, ['river', 'subcatchment', 'area', 'pfafstetter']])
            plot_events_timeseries(dis_cat[stn], events[stn], thresholds=stn_cat.loc[stn, ['rl1.5', 'rl2', 'rl5', 'rl20']],
                                   title=title, save=f'{out_folder}/no_events_{stn}.png')

    # correlation matrix
    corr = dis_cat.corr(method='spearman')
    # keep only upper diagonal
    corr = filter_correlation_matrix(corr, rho=None)

    # compute exceedance of the correlation threshold
    highly_correlated = corr > rho
    highly_correlated = highly_correlated.astype(int)
    highly_correlated[highly_correlated == 0] = np.nan

    # plot
    plt.figure()
    sns.heatmap(corr, vmin=0, vmax=1, cmap='Blues', cbar_kws={'label': 'Spearman correlation (-)', 'shrink': .66});
    sns.heatmap(highly_correlated, cmap='Reds', vmin=0.5, vmax=1.5, alpha=.75, cbar=None);

    # sort stations according to number of flood events
    stn_cat_3 = stn_cat.copy()
    stn_cat_3.sort_values([col], ascending=True, inplace=True)

    # correlation matrix
    corr_3 = dis_cat[stn_cat_3.index.to_list()].corr(method='spearman')
    # remove highly correlated stations
    corr_3 = filter_correlation_matrix(corr_3, rho=rho)
    stn_cat_3 = stn_cat_3.loc[corr_3.index]

    print('no. original points in the {0} catchment:\t{1}'.format(catchment, stn_cat.shape[0]))
    print('no. filtered points in the {0} catchment:\t{1}'.format(catchment, stn_cat_3.shape[0]))
    
    plt.figure()
    sns.heatmap(corr_3, vmin=0, vmax=1, cmap='Blues',
                cbar_kws={'label': 'Spearman correlation (-)', 'shrink': .66});

    stn_sets = {'all': stn_cat,
                'correlation_event-sorted': stn_cat_3}

    # sort all subsets equally
    for key, stns in stn_sets.items():
        stns.sort_values(['area'], ascending=True, inplace=True)
        stns.sort_values('pfafstetter', ascending=True, inplace=True)

    # table summarizing no. stations and events with every station set
    summary = pd.DataFrame(index=stn_sets.keys(), columns=['no_stations', 'p_stations_event', 'no_events'])
    for i, (key, stns) in enumerate(stn_sets.items()):
        summary.loc[key] = stns.shape[0], sum(stns[col] > 0), stns[col].sum()
    summary.p_stations_event /= summary.no_stations
    print(summary)

    if events.sum().sum() > 0:
        # plot maps of no. events for each of the station sets
        proj = ccrs.LambertAzimuthalEqualArea(central_longitude=10, central_latitude=52, false_easting=4321000, false_northing=3210000,
                                                  globe=ccrs.Globe(ellipse='GRS80'))
        nrows = 1
        ncols = int(np.ceil(len(stn_sets) / nrows))
        fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6 * ncols, 6 * nrows), 
                                 subplot_kw={'projection': proj}, constrained_layout=True)
        vmax = max(stn_sets['all'][col].max(), 2)
        for ax, (key, stns) in zip(axes.flatten(), stn_sets.items()):
            plot_events_map(stns.X, stns.Y, stns[col], rivers=rivers_cat, size=20, ax=ax, title=key, vmax=vmax, cbar=True)
        plt.colorbar(plot_events_map.colorbar, location='bottom', shrink=.4, label='no. events', ax=axes[:])
        plt.savefig(f'{out_folder}/no_events_map_{key}.png', dpi=300, bbox_inches='tight')
    
    # plot timeline of threshold exceedances
    fig, axes = plt.subplots(nrows=2, figsize=(12, 8), constrained_layout=True, sharex=True, sharey=True)
    thrs = ['rl2', 'rl5', 'rl20']
    for ax, (key, stns) in zip(axes, stn_sets.items()):
        exceedances_timeline(dis_cat, stns, thresholds=thrs, grid=True, title=key, ax=ax)
    plt.savefig(f'{out_folder}/exceedance_timeline.png', dpi=300, bbox_inches='tight')

    # export selected points
    stn_sets['correlation_event-sorted'].to_csv(out_file)
# Out:
# ADIGE
# -----
# no. stations in the Adige catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Adige catchment:	3
# no. filtered points in the Adige catchment:	2
#                          no_stations p_stations_event no_events
# all                                3         0.666667         2
# correlation_event-sorted           2              0.5         1
#
# ADOUR
# -----
# no. stations in the Adour catchment:	9
# Discharge timeseries:
# 3231	timesteps
# 9	stations
# no. stations with at least one event:	6
# total no. events:			14
# no. original points in the Adour catchment:	9
# no. filtered points in the Adour catchment:	4
#                          no_stations p_stations_event no_events
# all                                9         0.666667        14
# correlation_event-sorted           4             0.75         9
#
# AHTAVAN
# -------
# no. stations in the Ahtavan catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Ahtavan catchment:	1
# no. filtered points in the Ahtavan catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# AKHELOOS
# --------
# no. stations in the Akheloos catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			5
# no. original points in the Akheloos catchment:	1
# no. filtered points in the Akheloos catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         5
# correlation_event-sorted           1              1.0         5
#
# ALMANZORA
# ---------
# no. stations in the Almanzora catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Almanzora catchment:	1
# no. filtered points in the Almanzora catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ALSTERAN
# --------
# no. stations in the Alsteran catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Alsteran catchment:	1
# no. filtered points in the Alsteran catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ALTAELVA
# --------
# no. stations in the Altaelva catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Altaelva catchment:	2
# no. filtered points in the Altaelva catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# ANGERMANALVEN
# -------------
# no. stations in the Angermanalven catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Angermanalven catchment:	1
# no. filtered points in the Angermanalven catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ARBOGAAN
# --------
# no. stations in the Arbogaan catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Arbogaan catchment:	1
# no. filtered points in the Arbogaan catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ARNO
# ----
# no. stations in the Arno catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Arno catchment:	2
# no. filtered points in the Arno catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.5         1
# correlation_event-sorted           2              0.5         1
#
# ATRAN
# -----
# no. stations in the Atran catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Atran catchment:	1
# no. filtered points in the Atran catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# AUDE
# ----
# no. stations in the Aude catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Aude catchment:	4
# no. filtered points in the Aude catchment:	1
#                          no_stations p_stations_event no_events
# all                                4              0.0         0
# correlation_event-sorted           1              0.0         0
#
# AULNE
# -----
# no. stations in the Aulne catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Aulne catchment:	1
# no. filtered points in the Aulne catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# AVON
# ----
# no. stations in the Avon catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Avon catchment:	2
# no. filtered points in the Avon catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# BANN
# ----
# no. stations in the Bann catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Bann catchment:	2
# no. filtered points in the Bann catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.5         1
# correlation_event-sorted           2              0.5         1
#
# BARROW
# ------
# no. stations in the Barrow catchment:	11
# Discharge timeseries:
# 3231	timesteps
# 11	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Barrow catchment:	11
# no. filtered points in the Barrow catchment:	2
#                          no_stations p_stations_event no_events
# all                               11         0.090909         1
# correlation_event-sorted           2              0.5         1
#
# BESOR
# -----
# no. stations in the Besor catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Besor catchment:	2
# no. filtered points in the Besor catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# BESOS
# -----
# no. stations in the Besos catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Besos catchment:	1
# no. filtered points in the Besos catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# BLACKWATER
# ----------
# no. stations in the Blackwater catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	3
# total no. events:			8
# no. original points in the Blackwater catchment:	3
# no. filtered points in the Blackwater catchment:	1
#                          no_stations p_stations_event no_events
# all                                3              1.0         8
# correlation_event-sorted           1              1.0         4
#
# BLAVET
# ------
# no. stations in the Blavet catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Blavet catchment:	1
# no. filtered points in the Blavet catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# BOYNE
# -----
# no. stations in the Boyne catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Boyne catchment:	3
# no. filtered points in the Boyne catchment:	1
#                          no_stations p_stations_event no_events
# all                                3         0.666667         2
# correlation_event-sorted           1              1.0         1
#
# BUG
# ---
# no. stations in the Bug catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Bug catchment:	2
# no. filtered points in the Bug catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           2              0.0         0
#
# BUYUK MENDERES
# --------------
# no. stations in the Buyuk Menderes catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Buyuk Menderes catchment:	2
# no. filtered points in the Buyuk Menderes catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.5         1
# correlation_event-sorted           1              1.0         1
#
# BYAELVA
# -------
# no. stations in the Byaelva catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Byaelva catchment:	1
# no. filtered points in the Byaelva catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# BYSKE
# -----
# no. stations in the Byske catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Byske catchment:	1
# no. filtered points in the Byske catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# BZIPI
# -----
# no. stations in the Bzipi catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Bzipi catchment:	1
# no. filtered points in the Bzipi catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# CEYHAN
# ------
# no. stations in the Ceyhan catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Ceyhan catchment:	2
# no. filtered points in the Ceyhan catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.5         1
# correlation_event-sorted           2              0.5         1
#
# CHAPOMA
# -------
# no. stations in the Chapoma catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Chapoma catchment:	1
# no. filtered points in the Chapoma catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# CHAVANGA
# --------
# no. stations in the Chavanga catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Chavanga catchment:	1
# no. filtered points in the Chavanga catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# CHELMER
# -------
# no. stations in the Chelmer catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			7
# no. original points in the Chelmer catchment:	1
# no. filtered points in the Chelmer catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         7
# correlation_event-sorted           1              1.0         7
#
# CLYDE
# -----
# no. stations in the Clyde catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			6
# no. original points in the Clyde catchment:	2
# no. filtered points in the Clyde catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         6
# correlation_event-sorted           1              1.0         3
#
# CORRIB
# ------
# no. stations in the Corrib catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Corrib catchment:	1
# no. filtered points in the Corrib catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# CORUH
# -----
# no. stations in the Coruh catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Coruh catchment:	1
# no. filtered points in the Coruh catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# DAL
# ---
# no. stations in the Dal catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Dal catchment:	4
# no. filtered points in the Dal catchment:	4
#                          no_stations p_stations_event no_events
# all                                4              0.0         0
# correlation_event-sorted           4              0.0         0
#
# DANUBE
# ------
# no. stations in the Danube catchment:	453
# Discharge timeseries:
# 3231	timesteps
# 453	stations
# no. stations with at least one event:	195
# total no. events:			276
# no. original points in the Danube catchment:	453
# no. filtered points in the Danube catchment:	157
#                          no_stations p_stations_event no_events
# all                              453         0.430464       276
# correlation_event-sorted         157         0.452229       112
#
# DAUGAVA
# -------
# no. stations in the Daugava catchment:	13
# Discharge timeseries:
# 3231	timesteps
# 13	stations
# no. stations with at least one event:	4
# total no. events:			4
# no. original points in the Daugava catchment:	13
# no. filtered points in the Daugava catchment:	9
#                          no_stations p_stations_event no_events
# all                               13         0.307692         4
# correlation_event-sorted           9         0.222222         2
#
# DEE
# ---
# no. stations in the Dee catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	3
# total no. events:			6
# no. original points in the Dee catchment:	3
# no. filtered points in the Dee catchment:	2
#                          no_stations p_stations_event no_events
# all                                3              1.0         6
# correlation_event-sorted           2              1.0         4
#
# DNIEPER
# -------
# no. stations in the Dnieper catchment:	53
# Discharge timeseries:
# 3231	timesteps
# 53	stations
# no. stations with at least one event:	8
# total no. events:			10
# no. original points in the Dnieper catchment:	53
# no. filtered points in the Dnieper catchment:	36
#                          no_stations p_stations_event no_events
# all                               53         0.150943        10
# correlation_event-sorted          36         0.083333         5
#
# DNIESTER
# --------
# no. stations in the Dniester catchment:	11
# Discharge timeseries:
# 3231	timesteps
# 11	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Dniester catchment:	11
# no. filtered points in the Dniester catchment:	9
#                          no_stations p_stations_event no_events
# all                               11              0.0         0
# correlation_event-sorted           9              0.0         0
#
# DON
# ---
# no. stations in the Don catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Don catchment:	1
# no. filtered points in the Don catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# DORDOGNE
# --------
# no. stations in the Dordogne catchment:	10
# Discharge timeseries:
# 3231	timesteps
# 10	stations
# no. stations with at least one event:	7
# total no. events:			10
# no. original points in the Dordogne catchment:	10
# no. filtered points in the Dordogne catchment:	2
#                          no_stations p_stations_event no_events
# all                               10              0.7        10
# correlation_event-sorted           2              1.0         3
#
# DOURO
# -----
# no. stations in the Douro catchment:	29
# Discharge timeseries:
# 3231	timesteps
# 29	stations
# no. stations with at least one event:	13
# total no. events:			28
# no. original points in the Douro catchment:	29
# no. filtered points in the Douro catchment:	16
#                          no_stations p_stations_event no_events
# all                               29         0.448276        28
# correlation_event-sorted          16              0.5        19
#
# DRAMMEN
# -------
# no. stations in the Drammen catchment:	7
# Discharge timeseries:
# 3231	timesteps
# 7	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Drammen catchment:	7
# no. filtered points in the Drammen catchment:	3
#                          no_stations p_stations_event no_events
# all                                7              0.0         0
# correlation_event-sorted           3              0.0         0
#
# DRIN
# ----
# no. stations in the Drin catchment:	5
# Discharge timeseries:
# 3231	timesteps
# 5	stations
# no. stations with at least one event:	5
# total no. events:			13
# no. original points in the Drin catchment:	5
# no. filtered points in the Drin catchment:	3
#                          no_stations p_stations_event no_events
# all                                5              1.0        13
# correlation_event-sorted           3              1.0         9
#
# DRIVA
# -----
# no. stations in the Driva catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			3
# no. original points in the Driva catchment:	1
# no. filtered points in the Driva catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         3
# correlation_event-sorted           1              1.0         3
#
# EBRO
# ----
# no. stations in the Ebro catchment:	71
# Discharge timeseries:
# 3231	timesteps
# 71	stations
# no. stations with at least one event:	33
# total no. events:			47
# no. original points in the Ebro catchment:	71
# no. filtered points in the Ebro catchment:	34
#                          no_stations p_stations_event no_events
# all                               71         0.464789        47
# correlation_event-sorted          34         0.382353        20
#
# EDEN
# ----
# no. stations in the Eden catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Eden catchment:	2
# no. filtered points in the Eden catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ELBE
# ----
# no. stations in the Elbe catchment:	72
# Discharge timeseries:
# 3231	timesteps
# 72	stations
# no. stations with at least one event:	13
# total no. events:			20
# no. original points in the Elbe catchment:	72
# no. filtered points in the Elbe catchment:	29
#                          no_stations p_stations_event no_events
# all                               72         0.180556        20
# correlation_event-sorted          29         0.241379        12
#
# EMAN
# ----
# no. stations in the Eman catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Eman catchment:	1
# no. filtered points in the Eman catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# EMS
# ---
# no. stations in the Ems catchment:	5
# Discharge timeseries:
# 3231	timesteps
# 5	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Ems catchment:	5
# no. filtered points in the Ems catchment:	1
#                          no_stations p_stations_event no_events
# all                                5              0.0         0
# correlation_event-sorted           1              0.0         0
#
# ERNE
# ----
# no. stations in the Erne catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Erne catchment:	1
# no. filtered points in the Erne catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# EURAJOKI
# --------
# no. stations in the Eurajoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Eurajoki catchment:	1
# no. filtered points in the Eurajoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# EVROS
# -----
# no. stations in the Evros catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	2
# total no. events:			3
# no. original points in the Evros catchment:	3
# no. filtered points in the Evros catchment:	3
#                          no_stations p_stations_event no_events
# all                                3         0.666667         3
# correlation_event-sorted           3         0.666667         3
#
# EXE
# ---
# no. stations in the Exe catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Exe catchment:	1
# no. filtered points in the Exe catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# EYRE
# ----
# no. stations in the Eyre catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			3
# no. original points in the Eyre catchment:	1
# no. filtered points in the Eyre catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         3
# correlation_event-sorted           1              1.0         3
#
# FNJCSK
# ------
# no. stations in the Fnjcsk catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Fnjcsk catchment:	1
# no. filtered points in the Fnjcsk catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# FORTH
# -----
# no. stations in the Forth catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Forth catchment:	1
# no. filtered points in the Forth catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# FOYLE
# -----
# no. stations in the Foyle catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Foyle catchment:	1
# no. filtered points in the Foyle catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# GARONNE
# -------
# no. stations in the Garonne catchment:	24
# Discharge timeseries:
# 3231	timesteps
# 24	stations
# no. stations with at least one event:	14
# total no. events:			20
# no. original points in the Garonne catchment:	24
# no. filtered points in the Garonne catchment:	14
#                          no_stations p_stations_event no_events
# all                               24         0.583333        20
# correlation_event-sorted          14         0.571429        13
#
# GAUJA
# -----
# no. stations in the Gauja catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Gauja catchment:	1
# no. filtered points in the Gauja catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# GAULA
# -----
# no. stations in the Gaula catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Gaula catchment:	2
# no. filtered points in the Gaula catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# GEDIZ
# -----
# no. stations in the Gediz catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Gediz catchment:	1
# no. filtered points in the Gediz catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# GIDEALVEN
# ---------
# no. stations in the Gidealven catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Gidealven catchment:	1
# no. filtered points in the Gidealven catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# GLOMMA
# ------
# no. stations in the Glomma catchment:	18
# Discharge timeseries:
# 3231	timesteps
# 18	stations
# no. stations with at least one event:	7
# total no. events:			8
# no. original points in the Glomma catchment:	18
# no. filtered points in the Glomma catchment:	8
#                          no_stations p_stations_event no_events
# all                               18         0.388889         8
# correlation_event-sorted           8              0.5         5
#
# GOKSU
# -----
# no. stations in the Goksu catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Goksu catchment:	2
# no. filtered points in the Goksu catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# GOTA
# ----
# no. stations in the Gota catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Gota catchment:	4
# no. filtered points in the Gota catchment:	4
#                          no_stations p_stations_event no_events
# all                                4             0.25         1
# correlation_event-sorted           4             0.25         1
#
# GREAT OUSE
# ----------
# no. stations in the Great Ouse catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			4
# no. original points in the Great Ouse catchment:	2
# no. filtered points in the Great Ouse catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         4
# correlation_event-sorted           1              1.0         2
#
# GUADALHORCE
# -----------
# no. stations in the Guadalhorce catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Guadalhorce catchment:	3
# no. filtered points in the Guadalhorce catchment:	1
#                          no_stations p_stations_event no_events
# all                                3              0.0         0
# correlation_event-sorted           1              0.0         0
#
# GUADALQUIVIR
# ------------
# no. stations in the Guadalquivir catchment:	31
# Discharge timeseries:
# 3231	timesteps
# 31	stations
# no. stations with at least one event:	5
# total no. events:			5
# no. original points in the Guadalquivir catchment:	31
# no. filtered points in the Guadalquivir catchment:	20
#                          no_stations p_stations_event no_events
# all                               31          0.16129         5
# correlation_event-sorted          20             0.15         3
#
# GUADIANA
# --------
# no. stations in the Guadiana catchment:	36
# Discharge timeseries:
# 3231	timesteps
# 36	stations
# no. stations with at least one event:	13
# total no. events:			16
# no. original points in the Guadiana catchment:	36
# no. filtered points in the Guadiana catchment:	18
#                          no_stations p_stations_event no_events
# all                               36         0.361111        16
# correlation_event-sorted          18         0.222222         6
#
# GUDENA
# ------
# no. stations in the Gudena catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			3
# no. original points in the Gudena catchment:	1
# no. filtered points in the Gudena catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         3
# correlation_event-sorted           1              1.0         3
#
# HELGE
# -----
# no. stations in the Helge catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Helge catchment:	3
# no. filtered points in the Helge catchment:	2
#                          no_stations p_stations_event no_events
# all                                3         0.333333         1
# correlation_event-sorted           2              0.5         1
#
# HERAULT
# -------
# no. stations in the Herault catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Herault catchment:	2
# no. filtered points in the Herault catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# HVITA
# -----
# no. stations in the Hvita catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Hvita catchment:	2
# no. filtered points in the Hvita catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# IIJOKI
# ------
# no. stations in the Iijoki catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Iijoki catchment:	4
# no. filtered points in the Iijoki catchment:	2
#                          no_stations p_stations_event no_events
# all                                4              0.0         0
# correlation_event-sorted           2              0.0         0
#
# INDALSALVEN
# -----------
# no. stations in the Indalsalven catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Indalsalven catchment:	3
# no. filtered points in the Indalsalven catchment:	3
#                          no_stations p_stations_event no_events
# all                                3              0.0         0
# correlation_event-sorted           3              0.0         0
#
# ISOJOKI
# -------
# no. stations in the Isojoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Isojoki catchment:	1
# no. filtered points in the Isojoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# IYIDERE
# -------
# no. stations in the Iyidere catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Iyidere catchment:	1
# no. filtered points in the Iyidere catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# JKULS FJLLUM
# ------------
# no. stations in the Jkuls Fjllum catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	2
# total no. events:			5
# no. original points in the Jkuls Fjllum catchment:	3
# no. filtered points in the Jkuls Fjllum catchment:	1
#                          no_stations p_stations_event no_events
# all                                3         0.666667         5
# correlation_event-sorted           1              1.0         3
#
# JORDAN
# ------
# no. stations in the Jordan catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	2
# total no. events:			11
# no. original points in the Jordan catchment:	3
# no. filtered points in the Jordan catchment:	2
#                          no_stations p_stations_event no_events
# all                                3         0.666667        11
# correlation_event-sorted           2              1.0        11
#
# JUCAR
# -----
# no. stations in the Jucar catchment:	23
# Discharge timeseries:
# 3231	timesteps
# 23	stations
# no. stations with at least one event:	14
# total no. events:			26
# no. original points in the Jucar catchment:	23
# no. filtered points in the Jucar catchment:	12
#                          no_stations p_stations_event no_events
# all                               23         0.608696        26
# correlation_event-sorted          12             0.75        15
#
# KALAJOKI
# --------
# no. stations in the Kalajoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kalajoki catchment:	1
# no. filtered points in the Kalajoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KALIX
# -----
# no. stations in the Kalix catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kalix catchment:	2
# no. filtered points in the Kalix catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           2              0.0         0
#
# KALMIUS
# -------
# no. stations in the Kalmius catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			4
# no. original points in the Kalmius catchment:	1
# no. filtered points in the Kalmius catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         4
# correlation_event-sorted           1              1.0         4
#
# KARA
# ----
# no. stations in the Kara catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Kara catchment:	1
# no. filtered points in the Kara catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# KARVIANJOKI
# -----------
# no. stations in the Karvianjoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Karvianjoki catchment:	1
# no. filtered points in the Karvianjoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# KASARI
# ------
# no. stations in the Kasari catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kasari catchment:	1
# no. filtered points in the Kasari catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KEM
# ---
# no. stations in the Kem catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kem catchment:	1
# no. filtered points in the Kem catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KEMIJOKI
# --------
# no. stations in the Kemijoki catchment:	13
# Discharge timeseries:
# 3231	timesteps
# 13	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kemijoki catchment:	13
# no. filtered points in the Kemijoki catchment:	5
#                          no_stations p_stations_event no_events
# all                               13              0.0         0
# correlation_event-sorted           5              0.0         0
#
# KIIMINGINJOKI
# -------------
# no. stations in the Kiiminginjoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kiiminginjoki catchment:	1
# no. filtered points in the Kiiminginjoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KIZILIRMAK
# ----------
# no. stations in the Kizilirmak catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kizilirmak catchment:	2
# no. filtered points in the Kizilirmak catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           2              0.0         0
#
# KOCACAY
# -------
# no. stations in the Kocacay catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kocacay catchment:	2
# no. filtered points in the Kocacay catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           2              0.0         0
#
# KOEPRUE
# -------
# no. stations in the Koeprue catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Koeprue catchment:	1
# no. filtered points in the Koeprue catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# KOKEM
# -----
# no. stations in the Kokem catchment:	8
# Discharge timeseries:
# 3231	timesteps
# 8	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Kokem catchment:	8
# no. filtered points in the Kokem catchment:	4
#                          no_stations p_stations_event no_events
# all                                8            0.125         1
# correlation_event-sorted           4             0.25         1
#
# KOLA
# ----
# no. stations in the Kola catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kola catchment:	2
# no. filtered points in the Kola catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KOLVITSA
# --------
# no. stations in the Kolvitsa catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Kolvitsa catchment:	1
# no. filtered points in the Kolvitsa catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# KRKA
# ----
# no. stations in the Krka catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Krka catchment:	1
# no. filtered points in the Krka catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KUBAN
# -----
# no. stations in the Kuban catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	1
# total no. events:			5
# no. original points in the Kuban catchment:	4
# no. filtered points in the Kuban catchment:	3
#                          no_stations p_stations_event no_events
# all                                4             0.25         5
# correlation_event-sorted           3         0.333333         5
#
# KURA
# ----
# no. stations in the Kura catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	1
# total no. events:			5
# no. original points in the Kura catchment:	4
# no. filtered points in the Kura catchment:	4
#                          no_stations p_stations_event no_events
# all                                4             0.25         5
# correlation_event-sorted           4             0.25         5
#
# KYMIJOKI
# --------
# no. stations in the Kymijoki catchment:	12
# Discharge timeseries:
# 3231	timesteps
# 12	stations
# no. stations with at least one event:	10
# total no. events:			14
# no. original points in the Kymijoki catchment:	12
# no. filtered points in the Kymijoki catchment:	6
#                          no_stations p_stations_event no_events
# all                               12         0.833333        14
# correlation_event-sorted           6         0.833333         8
#
# KYMIJOKI - GULF OF FINLAND
# --------------------------
# no. stations in the Kymijoki - Gulf of Finland catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Kymijoki - Gulf of Finland catchment:	1
# no. filtered points in the Kymijoki - Gulf of Finland catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# KYRONJOKI
# ---------
# no. stations in the Kyronjoki catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Kyronjoki catchment:	2
# no. filtered points in the Kyronjoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# LAGAN
# -----
# no. stations in the Lagan catchment:	3
# Discharge timeseries:
# 3231	timesteps
# 3	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lagan catchment:	3
# no. filtered points in the Lagan catchment:	2
#                          no_stations p_stations_event no_events
# all                                3              0.0         0
# correlation_event-sorted           2              0.0         0
#
# LAGARFLJOT
# ----------
# no. stations in the Lagarfljot catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lagarfljot catchment:	1
# no. filtered points in the Lagarfljot catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LAGEN
# -----
# no. stations in the Lagen catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lagen catchment:	2
# no. filtered points in the Lagen catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LAKHISH
# -------
# no. stations in the Lakhish catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			8
# no. original points in the Lakhish catchment:	1
# no. filtered points in the Lakhish catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         8
# correlation_event-sorted           1              1.0         8
#
# LAPUANJOKI
# ----------
# no. stations in the Lapuanjoki catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lapuanjoki catchment:	2
# no. filtered points in the Lapuanjoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LAY
# ---
# no. stations in the Lay catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lay catchment:	1
# no. filtered points in the Lay catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LESTIJOKI
# ---------
# no. stations in the Lestijoki catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lestijoki catchment:	1
# no. filtered points in the Lestijoki catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LIELUPE
# -------
# no. stations in the Lielupe catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lielupe catchment:	2
# no. filtered points in the Lielupe catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LIFFEY
# ------
# no. stations in the Liffey catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Liffey catchment:	1
# no. filtered points in the Liffey catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# LIMA
# ----
# no. stations in the Lima catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Lima catchment:	2
# no. filtered points in the Lima catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# LIRI
# ----
# no. stations in the Liri catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Liri catchment:	2
# no. filtered points in the Liri catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              1.0         2
# correlation_event-sorted           1              1.0         1
#
# LJUNGAN
# -------
# no. stations in the Ljungan catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Ljungan catchment:	2
# no. filtered points in the Ljungan catchment:	1
#                          no_stations p_stations_event no_events
# all                                2              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LJUSNAN
# -------
# no. stations in the Ljusnan catchment:	4
# Discharge timeseries:
# 3231	timesteps
# 4	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Ljusnan catchment:	4
# no. filtered points in the Ljusnan catchment:	3
#                          no_stations p_stations_event no_events
# all                                4             0.25         1
# correlation_event-sorted           3         0.333333         1
#
# LLOBREGAT
# ---------
# no. stations in the Llobregat catchment:	7
# Discharge timeseries:
# 3231	timesteps
# 7	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Llobregat catchment:	7
# no. filtered points in the Llobregat catchment:	2
#                          no_stations p_stations_event no_events
# all                                7              0.0         0
# correlation_event-sorted           2              0.0         0
#
# LOCHY
# -----
# no. stations in the Lochy catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Lochy catchment:	1
# no. filtered points in the Lochy catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LOIRE
# -----
# no. stations in the Loire catchment:	72
# Discharge timeseries:
# 3231	timesteps
# 72	stations
# no. stations with at least one event:	41
# total no. events:			55
# no. original points in the Loire catchment:	72
# no. filtered points in the Loire catchment:	24
#                          no_stations p_stations_event no_events
# all                               72         0.569444        55
# correlation_event-sorted          24         0.708333        24
#
# LUGA
# ----
# no. stations in the Luga catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Luga catchment:	1
# no. filtered points in the Luga catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LULEAELVEN
# ----------
# no. stations in the Luleaelven catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Luleaelven catchment:	1
# no. filtered points in the Luleaelven catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# LUNE
# ----
# no. stations in the Lune catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Lune catchment:	1
# no. filtered points in the Lune catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# MALSELV
# -------
# no. stations in the Malselv catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			2
# no. original points in the Malselv catchment:	1
# no. filtered points in the Malselv catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         2
# correlation_event-sorted           1              1.0         2
#
# MANDAL
# ------
# no. stations in the Mandal catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Mandal catchment:	1
# no. filtered points in the Mandal catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# MARTA
# -----
# no. stations in the Marta catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Marta catchment:	1
# no. filtered points in the Marta catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# MEDWAY
# ------
# no. stations in the Medway catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			2
# no. original points in the Medway catchment:	1
# no. filtered points in the Medway catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         2
# correlation_event-sorted           1              1.0         2
#
# MERSEY
# ------
# no. stations in the Mersey catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			2
# no. original points in the Mersey catchment:	1
# no. filtered points in the Mersey catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         2
# correlation_event-sorted           1              1.0         2
#
# MIJARES
# -------
# no. stations in the Mijares catchment:	6
# Discharge timeseries:
# 3231	timesteps
# 6	stations
# no. stations with at least one event:	6
# total no. events:			14
# no. original points in the Mijares catchment:	6
# no. filtered points in the Mijares catchment:	4
#                          no_stations p_stations_event no_events
# all                                6              1.0        14
# correlation_event-sorted           4              1.0        11
#
# MINHO
# -----
# no. stations in the Minho catchment:	6
# Discharge timeseries:
# 3231	timesteps
# 6	stations
# no. stations with at least one event:	2
# total no. events:			2
# no. original points in the Minho catchment:	6
# no. filtered points in the Minho catchment:	3
#                          no_stations p_stations_event no_events
# all                                6         0.333333         2
# correlation_event-sorted           3         0.666667         2
#
# MOALVEN
# -------
# no. stations in the Moalven catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Moalven catchment:	1
# no. filtered points in the Moalven catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# MONDEGO
# -------
# no. stations in the Mondego catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			2
# no. original points in the Mondego catchment:	1
# no. filtered points in the Mondego catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         2
# correlation_event-sorted           1              1.0         2
#
# MORRUMSAN
# ---------
# no. stations in the Morrumsan catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Morrumsan catchment:	1
# no. filtered points in the Morrumsan catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# MOTALA STROEM
# -------------
# no. stations in the Motala Stroem catchment:	2
# Discharge timeseries:
# 3231	timesteps
# 2	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Motala Stroem catchment:	2
# no. filtered points in the Motala Stroem catchment:	2
#                          no_stations p_stations_event no_events
# all                                2              0.5         1
# correlation_event-sorted           2              0.5         1
#
# MOY
# ---
# no. stations in the Moy catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Moy catchment:	1
# no. filtered points in the Moy catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# NAATAMO
# -------
# no. stations in the Naatamo catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Naatamo catchment:	1
# no. filtered points in the Naatamo catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              0.0         0
# correlation_event-sorted           1              0.0         0
#
# NAMSEN
# ------
# no. stations in the Namsen catchment:	1
# Discharge timeseries:
# 3231	timesteps
# 1	stations
# no. stations with at least one event:	1
# total no. events:			1
# no. original points in the Namsen catchment:	1
# no. filtered points in the Namsen catchment:	1
#                          no_stations p_stations_event no_events
# all                                1              1.0         1
# correlation_event-sorted           1              1.0         1
#
# NARVA
# -----
# no. stations in the Narva catchment:	7
# Discharge timeseries:
# 3231	timesteps
# 7	stations
# no. stations with at least one event:	0
# total no. events:			0
# no. original points in the Narva catchment:	7
# no. filtered points in the Narva catchment:	5
#                          no_stations p_stations_event no_events
# all                                7              0.0         0
# correlation_event-sorted           5              0.0         0
